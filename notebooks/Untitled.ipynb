# %%
## JOSS API DEMO

# %%
pdbA = "../data/1A2K_r_u.pdb"
pdbB = "../data/1A2K_l_u.pdb"
trans_sample = "../data/1A2K_transformations_sample.json"

from pcmap import contactMap

# %%
contactMap(trans_sample)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 contactMap(trans_sample)
#
# File ~/work/projects/pcmap/src/pcmap/__init__.py:170, in contactMap(proteinA, proteinB, enrich, **kwargs)
#     166 lcMap = isinstance(proteinA, list)
#     168 assert_enrich_valid(proteinA, proteinB, enrich, **kwargs)
# --> 170 pdbREC = pypstruct.parseFilePDB(proteinA)\
#     171          if not lcMap\
#     172          else [ pypstruct.parseFilePDB(_).atomDictorize\
#     173                 for _ in proteinA ]
#     175 if not proteinB is None: #Dimer(s)
#     176     pdbLIG = pypstruct.parseFilePDB(proteinB)\
#     177              if not lcMap\
#     178              else [ pypstruct.parseFilePDB(_).atomDictorize\
#     179                     for _ in proteinB ]
#
# ...

# %%
contactMap(pdbA, pdbB)
# Out:
# {'type': 'contactList',
#  'data': [{'root': {'resID': '69 ', 'chainID': 'A'},
#    'partners': [{'resID': '76 ', 'chainID': 'A'}]},
#   {'root': {'resID': '41 ', 'chainID': 'B'},
#    'partners': [{'resID': '72 ', 'chainID': 'A'},
#     {'resID': '73 ', 'chainID': 'A'}]},
#   {'root': {'resID': '42 ', 'chainID': 'B'},
#    'partners': [{'resID': '72 ', 'chainID': 'A'},
#     {'resID': '74 ', 'chainID': 'A'},
#     {'resID': '73 ', 'chainID': 'A'}]},
#   {'root': {'resID': '59 ', 'chainID': 'B'},
#    'partners': [{'resID': '72 ', 'chainID': 'A'},
#     {'resID': '71 ', 'chainID': 'A'}]},
#   {'root': {'resID': '60 ', 'chainID': 'B'},
#    'partners': [{'resID': '71 ', 'chainID': 'A'}]},
#   {'root': {'resID': '94 ', 'chainID': 'B'},
#    'partners': [{'resID': '71 ', 'chainID': 'A'},
#     {'resID': '68 ', 'chainID': 'A'}]},
#   {'root': {'resID': '95 ', 'chainID': 'B'},
#    'partners': [{'resID': '67 ', 'chainID': 'A'}]},
#   {'root': {'resID': '97 ', 'chainID': 'B'},
# ...
